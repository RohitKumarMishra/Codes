# %% [markdown]
# | [Contents](https://github.com/RohitKumarMishra/Codes/blob/masterTOC.ipynb) | [Type Conversion using Global Functions](https://github.com/RohitKumarMishra/Codes/blob/master/Type Conversion using Global Functions.ipynb) >

# %% [markdown]
# #How to check the data type of a literal (Trainer Hands On)

# %%
type (10.6)
# Out:
# float

# %%
type (True)
# Out:
# bool

# %%
type (False)
# Out:
# bool

# %%
type ('FORSK')
# Out:
# str

# %%
type ("FORSK")
# Out:
# str

# %%
type ('''FORSK''')
# Out:
# str

# %%
type ('''FORSK''')
# Out:
# str

# %%
type ("""FORSK""")
# Out:
# str

# %%
type ( None )
# Out:
# NoneType
