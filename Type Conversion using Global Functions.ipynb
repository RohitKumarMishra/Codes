# %% [markdown]
# < [Use Of Primitive Data Types](https://github.com/RohitKumarMishra/Codes/blob/master/Use Of Primitive Data Types.ipynb) | [Contents](https://github.com/RohitKumarMishra/Codes/blob/masterTOC.ipynb) | [How to store data in Python variables](https://github.com/RohitKumarMishra/Codes/blob/master/How to store data in Python variables.ipynb) >

# %% [markdown]
# # Type Conversion using Global Functions
#
#   int()
#
#   float()
#
#   str()
#
#   bool()

# %%
#How to convert the data type (Trainer Hands On)
int (4)
# Out:
# 4

# %%
int (10.6)
# Out:
# 10

# %%
int ("10")
# Out:
# 10

# %%
int (True)
# Out:
# 1

# %%
float (4)
# Out:
# 4.0

# %%
float (10.6)
# Out:
# 10.6

# %%
float ("10")
# Out:
# 10.0

# %%
float (True)
# Out:
# 1.0

# %%
str (4)
# Out:
# '4'

# %%
str (10.6)
# Out:
# '10.6'

# %%
str ("10")
# Out:
# '10'

# %%
str (True)
# Out:
# 'True'

# %%
bool (4)
# Out:
# True

# %%
bool (10.6)
# Out:
# True

# %%
bool ("10")
# Out:
# True

# %%
bool (True)
# Out:
# True

# %%
 
bool (1)
# Out:
# True

# %%
bool (0)
# Out:
# False

# %%
bool (True)
# Out:
# True

# %%
bool (False)

#Single Line Commenting (Trainer Hands On)
#Using HASH or POUND ( # )
# Out:
# False
